# %%
# 발급받은 API 키 설정
OPENAI_API_KEY = ""

# 모델 - GPT 3.5 Turbo 선택
GPT_MODEL_NAME = "gpt-3.5-turbo"

SAVE_FILE_DIR_PATH = "./results/"

# %%
import os
import dataclasses
import datetime
import time
import tqdm
import openai
import argparse
import json

from pprint import PrettyPrinter

@dataclasses.dataclass
class TextMessage :
    """
    KISA에서 제공하는 스팸 문자 csv 파일 내용에 대응하는 데이터 클래스
    """
    title : str      = None # 문자 제목
    label : str      = None # 문자 타입
    content : str    = None # 문지 내용
    time1 : datetime = None #
    time2 : datetime = None #
    chat_gpt_response : str = None # chatGPT 답변 내용을 저장함

    def __init__(self, input_txt_lines) :
        self.parseRawInput(input_txt_lines)

    def parseRawInput(self, input_txt_lines) :
        time_str1, time_str2, self.label, self.content = input_txt_lines[0].split("[(KISA)]")
        self.time1 = datetime.datetime.strptime(time_str1.removeprefix("[(KISA:SOL)]"), "%Y%m%d%H%M")
        self.time2 = datetime.datetime.strptime(time_str2, "%Y%m%d%H%M")
        for line in input_txt_lines[1:-1] :
            self.content += line
        self.title = input_txt_lines[-1].removesuffix("[(KISA:EOL)]\n")


def parseKISASpamDataFile(file_path) :
    """
    kisa 에서 제공하는 스팸 데이터 파일을 파싱한다.
    """
    with open(file_path, "r") as fp :
        data_raw = fp.readlines()[1:]

    SOL_IDX_LIST = list(filter(
        lambda x : False if x is False else True,
        list(map(
            lambda line_idx, string : line_idx if "[(KISA:SOL)]" in string else False,
            range(len(data_raw)),
            data_raw
        ))
    ))
    EOL_IDX_LIST = list(filter(
        lambda x : False if x is False else True,
        list(map(
            lambda line_idx, string : line_idx if "[(KISA:EOL)]" in string else False,
            range(len(data_raw)),
            data_raw
        ))
    ))
    assert len(SOL_IDX_LIST) == len(EOL_IDX_LIST), """
        number of SOL lines and EOL lines are different.
        check if data is valid
    """
    text_message_list = []
    for text_data_start_line_idx, text_data_end_line_idx in zip(SOL_IDX_LIST, EOL_IDX_LIST) :
        text_message_list.append(
            TextMessage(input_txt_lines = data_raw[
                text_data_start_line_idx:text_data_end_line_idx + 1
            ])
        )
    return text_message_list

def queryQuestions(
    model_name,
    question_line_list,
    message_line_list,
    question_messsage_connection
) :
    """
    chatGPT 에게 쿼리를 날리고 답변을 모아 리턴한다
    
    args :
        model_name :
            model name to use in openapi Chat API
        question_line_list :
            list of question strings
        message_line_list :
            list of message strings
        question_messsage_connection :
            string to connect question and message
    """
    with tqdm.tqdm(total=len(question_line_list) * len(message_line_list)) as pbar :
        query_response_list = []
        for message_line in message_line_list :
            for question_line in question_line_list :
                result = {
                    "succeed":False
                }
                try :
                    query_content = question_line + question_messsage_connection + message_line
                    messages = [{
                        "role" : "user",
                        "content" : query_content
                    }]
                    response = openai.ChatCompletion.create(
                        model=model_name,
                        messages=messages
                    )
                    result["succeed"] = True
                    result["question_message"] = question_line
                    result["text_message"] = message_line
                    result["query_content"] = query_content
                    result["respone"] = response['choices'][0]['message']['content']
                except Exception as e :
                    result["error"] = str(e)
                query_response_list.append(result)

                pbar.update(1)
    return query_response_list

# %%
parser = argparse.ArgumentParser()
parser.add_argument("-a", "--api_key", help = "api key")
parser.add_argument("-n", "--model_name", default = "gpt-3.5-turbo", help = "chatGPT model name")
parser.add_argument("-c", "--question_message_connection", help = "connection message between question line and message line")
parser.add_argument("-q", "--question_file", default = "./question.txt", help = "question file path")
parser.add_argument("-d", "--data_file", help = "data file path")
parser.add_argument("-s", "--spam_file", help = "spam flie path")

args = parser.parse_args( # ipython notebook 파일 안에서는 이렇게 args 파라미터를 주어야 제대로 동작한다.
    args=[
        "-a", OPENAI_API_KEY,
        "-n", GPT_MODEL_NAME,
        #"-d", "data.txt",
        "-s", "./data/20220830_GBL.csv",
        '-c', "\n",
    ]
)

# openai API 키 인증
openai.api_key = args.api_key

with open(args.question_file, "r") as fp :
    question_line_list = fp.read().split("\n")

data_message_line_list = None
if args.data_file :
    with open(args.data_file, 'r') as fp :
        data_message_line_list = fp.read().split('\n')

    print(f"processing spam message from data file {args.data_file}")

    query_response_list = queryQuestions(
        model_name = args.model_name,
        question_line_list = question_line_list,
        message_line_list = data_message_line_list,
        question_messsage_connection = args.question_message_connection
    )

spam_message_line_list = None
if args.spam_file :
    spam_message_line_list = list(map(
        lambda spam_text_data : spam_text_data.content,
        parseKISASpamDataFile(args.spam_file)
    ))

    query_response_list = queryQuestions(
        model_name = args.model_name,
        question_line_list = question_line_list,
        message_line_list = spam_message_line_list,
        question_messsage_connection = args.question_message_connection
    )
# Out:
#  16%|█▌        | 2379/14756 [2:31:55<34:13,  6.03it/s]

# %%
query_response_list
# Out:
# [{'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': '이것은 스팸문자일까?\n-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': '잠재적으로 이 문자는 스팸 문자일 수 있습니다. 이유는 다음과 같습니다.\n\n1. "폭탄"이라는 제목: 이는 광고성 문자의 주요 특징 중 하나입니다. 제목이 눈에 띄고 시선을 끌기 위해 사용됩니다.\n\n2. 숫자와 수식 +: 이는 일반적으로 할인 또는 프로모션을 나타내는 알림이 스팸 문자와 연관되어 있습니다.\n\n3. 짧은 URL 링크 (bit.ly): 짧은 URL은 수상하게 느껴질 수 있으며, 사기성 링크가 될 수 있습니다.\n\n결론적으로, 이 문자는 당신에게 어떤 혜택을 제공하지만 온전히 신뢰할 수 있는 출처인지 확인해야합니다. 외부 링크를 클릭하기 전에 소스에 대해 조사를 진행하고 일회성 비밀번호 등의 개인 정보를 요구하는 사이트에 접속하지 않도록 주의해야 합니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': 'is this a spam message?\n-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': 'It is not possible to determine if this message is spam without more context.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': '주어진 정보만 가지고는 정확한 판단을 내리기 어렵습니다. 하지만 주어진 정보만으로는 이 문자가 사기 스팸문자인지, 단순 광고성 문자인지를 파악하기 어렵습니다. 해당 문자의 내용과 발송자에 대한 추가 정보가 있어야 더 정확한 판단이 가능합니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': 'It is not possible to determine from the given message alone whether it is a scamming spam message or a regular advertisement message. It is always important to exercise caution and verify the credibility of any unsolicited or suspicious messages before taking any action or providing personal information.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': '이것은 스팸문자일까?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': '주어진 정보만으로는 스팸 문자인지 확인할 수 없습니다. 스팸 여부를 판별하기 위해서는 해당 링크를 클릭하거나 문구에 포함된 번호로 전화를 거는 등 추가적인 점검이 필요합니다. 스팸 문자일 가능성이 있거나 의심스러운 경우, 해당 메시지를 무시하는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': 'is this a spam message?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': 'Based on the given message, it is not possible to determine with certainty if it is a spam message or not.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': '이 문자는 광고성 문자로 보입니다. 작성된 문자에는 사기의 의도를 나타내는 요소가 없으며, 제품 또는 서비스를 홍보하는 내용이 포함되어 있습니다. 사기 스팸문자의 경우 개인 정보를 요구하거나 의심스러운 링크를 포함하고 있을 수 있습니다. 하지만 이 문자에는 그러한 요소가 없기 때문에 일반적으로 광고성 문자로 간주됩니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': 'Based on the limited information provided, it is difficult to determine whether this message is a scam or a regular advertisement. It is always recommended to exercise caution when clicking on unfamiliar links or providing personal information.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': '이것은 스팸문자일까?\n[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': '이것은 스팸문자로 보일 수 있습니다. 스팸 문자에서는 종종 협박적이거나 유혹적인 내용과 함께 링크를 제공하는 것이 흔한데, 이 문자 역시 추천 링크와 함께 이상한 코드가 첨부되어 있습니다. 이러한 메시지에 대해 의심을 갖는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': 'is this a spam message?\n[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': 'It is difficult to determine whether this message is a spam without more information. However, caution should generally be exercised when receiving unsolicited messages with unknown links, as they can potentially be malicious or spam. It is recommended to not click on unknown links and to delete such messages.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': '이 문자는 광고성 문자일 가능성이 높습니다. "폭탄"이라는 제목과, 다양한 금액과 혜택을 알리는 내용이 포함되어 있습니다. 사기 스팸문자인지 여부를 100% 확정할 수는 없으므로 조심하는 것이 좋습니다. 만약 이 문자와 관련된 이상한 링크나 요구사항이 있다면 당장 조치를 취하지 않고, 문자를 삭제하고 무시하는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[국제발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n',
#   'respone': 'This message appears to be a scamming spam message.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'query_content': '이것은 스팸문자일까?\n[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'respone': '제공된 정보로는 이것이 스팸 문자인지 확인하기 어렵습니다. 그러나 정보의 출처가 확실하지 않거나 이상한 링크 또는 요청이 포함되어 있다면 스팸 문자일 가능성이 높습니다. 소심하게 의심스러운 문자이면 받지 않고 삭제하는 것이 가장 안전합니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'query_content': 'is this a spam message?\n[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'respone': 'It does not appear to be a spam message. It seems to be a response to an inquiry regarding SBS Academy Game School.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'respone': '이 문자는 광고성 문자이며, SBS아카데미게임학원에 대한 안내와 이벤트에 대해 연락하여 설명해줄 예정이라고 말하고 있습니다. 따라서 이 문자는 사기 스팸문자가 아닙니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[Web발신]문의해주셔서 감사합니다. 직영점만의 특별함! 높은 취업률을 자랑하는 SBS아카데미게임학원! 자세한 안내를 위해 담당자가 문의하신 내용 및 이벤트에 대해 연락드려 설명드릴 예정입니다. 잠시만 기다려 주시길 바랍니다. *문의량이 많아 안내가 지연될 수 있는 점 양해 부탁드립니다.\n',
#   'respone': 'Based on the message provided, it appears to be a regular advertisement message rather than a scamming spam message. The message thanks the recipient for their inquiry and mentions a specific organization, SBS Academy Game School, which prides itself on a high employment rate. It states that a representative will contact the recipient to provide further details about their inquiry and any events they may be interested in. It also mentions that there may be delays in response due to a high volume of inquiries, which is a common practice in legitimate businesses.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'query_content': '이것은 스팸문자일까?\n[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'respone': '이것은 광고 메시지이므로 스팸문자로 분류될 수 있습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'query_content': 'is this a spam message?\n[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'respone': 'Yes, this message appears to be a spam message as it promotes a product and includes a link and contact information for ordering.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'respone': '이 메시지는 광고성 문자이며, 우울증 치료제인 "침향진환"을 판매하고 있습니다. 또한, 구매자에게 추가로 "금단녹삼"을 제공하는 것을 약속하고 있습니다. 이 메시지는 스팸문자로 간주될 수도 있으며, 나중에 추가로 문자를 받지 않기 원하는 경우에는 거부번호를 사용하여 수신을 거부할 수 있습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[Web발신](광고)금단 에프앤디★ 침향진환을 구매하시는 모든 고객분들에게녹용과 홍삼을 진하게 고아서 한포에 농축해서 만든  ( 금단녹삼 )을 드립니다.★지금 주문 전화  >> 080-865-5050★ 지금 주문 링크 >> https://me2.do/FDlMuQkp금단미인 "침향환은 숙성환" 입니다.좋은 재료를 오래 끓여 고를 내어 7일간 숙성하여 2일간 건조한 후 손으로 정성껏 빚은 한알의 보약제가 빚은 공진단 처방 그대로 ...*★침향 두배 함량★ -효과 좋고 귀한 약재로 이루어진 약이지만, 가격이 비싸서 쉽게 권하지 못했던 공진단을 처방 그대로 하되사향대신 좋은 침향으로 대체하여 충분히 넣고, 다른 재료는 공진단과 같은 재료로 하였습니다.녹용 (러시아산)침향 (인도네시아산 정품)인삼 (전북진안에서 재배된 6년근)당귀 (강원 평창군 진부면)숙지황 (경북 군위 9증9포)산수유 (전남 구례군 산동면)벌꿀 (국내산)+ 부재료재료의 함량에 비해 아주 진하며 정성이 담겨있습니다.또한 숙성 발효되어 오랜 기간 두고 드릴 수 있습니다.타브랜드와 금단미인 침향환의 차별성은전통 공진단 제조 방식 그대로홈쇼핑에서 판매하는 제품처럼가루 내어 공장에서 만든 제품이 아닙니다.5일간 고를 내어 2일간 건조시킨 후 손으로 빚었습니다.....*침향진환 1(20환)+ 금단녹삼 1    135.000침향진환 2(40환)+ 금단녹삼 2    265.000침향진환 3(60환)+ 금단녹삼 3    380.000침향진환 4(80환)+ 금단녹삼 4    498.000침향진환 5(100환)+ 금단녹삼 5   615.000침향진환 구매하는 모든 고객에게 추가로 금단녹삼을 증정드립니다......*무료거부 0808100095인증5072134\n\n',
#   'respone': 'This message appears to be an advertisement message. However, it is always important to exercise caution when receiving unsolicited messages and to verify the legitimacy of the sender and any offers before taking any action or providing personal information.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'query_content': '이것은 스팸문자일까?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'respone': '이 문자는 스팸 문자일 가능성이 있습니다. 외국에서 발신된 메시지이며, 이상한 내용이 포함되어 있고, 알 수 없는 링크가 첨부되어 있습니다. 주의가 필요합니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'query_content': 'is this a spam message?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'respone': 'It is difficult to determine if this is a spam message without further context. However, the use of terms like "폭탄" (bomb) and the shortened URL could indicate that it may be suspicious. It is always advisable to exercise caution and avoid clicking on unfamiliar or suspicious links.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'respone': '이 문자는 광고성 문자로 보입니다. 사기 스팸문자가 아닌 것으로 보이며, 상품 또는 서비스를 홍보하고 있습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[국외발신]-폭탄-  신규 3+2 10+5 20+7 30+10 50+15 100+30  *bit.ly/3PDGdTL 코드자동\n\n',
#   'respone': 'Based on the limited information provided, it is difficult to determine whether this is a scam or a regular advertisement message. However, the message seems suspicious as it includes terms like "bomb" and a shortened link that leads to an unknown destination. It is always advisable to exercise caution when encountering such messages and avoid clicking on unfamiliar links.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': 'MMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'query_content': '이것은 스팸문자일까?\nMMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'respone': '이 메시지는 스팸 문자로 보입니다. 일반적으로 스팸 메시지는 회원 가입이나 번호 발급과 같은 이유로 메시지를 보내지 않습니다. 또한, 환불과 같은 약속이 있는 메시지도 스팸으로 간주될 수 있습니다. 즉, 이 메시지는 조심해야합니다. 제공된 링크도 클릭하지 않는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': 'MMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'query_content': 'is this a spam message?\nMMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'respone': 'Based on the content of the message, it is possible that this is a spam message. It includes a suspicious link and makes excessive promises about winning and refunds. It is advisable to exercise caution and not click on any unfamiliar or suspicious links.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': 'MMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\nMMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'respone': '주어진 문자 내용으로는 정확한 판단을 내리기 어렵습니다. 그러나 몇 가지 사전 조치를 취할 수 있습니다.\n\n1. 보낸 사람이 알려지지 않은 번호인 경우, 그리고 회신이나 문의가 불가능한 경우에는 주의해야 합니다.\n2. 해당 문자가 불법적인 행위나 사회적 악영향을 끼칠 수 있는 내용을 포함하고 있는 경우, 너무 좋아보이거나 현실적으로 불가능한 혜택을 약속하는 경우, 그리고 개인 정보를 요구하는 경우에는 사기 문자일 가능성이 큽니다.\n3. 문자에 제공된 링크가 의심스러운 사이트로 연결되는 경우에도 주의해야 합니다. 이러한 사이트는 자신의 개인 정보를 획득하려는 사이버 범죄자에 의해 생성될 수 있습니다.\n4. 만약 이러한 문자가 반복적으로 발생한다면, 이를 자신의 통신사에 신고해주십시오. 그들은 이러한 스팸 문자에 대한 조치를 취할 것입니다.\n\n하지만 기본적으로는, 받은 문자가 의심스러운 경우 그것을 무시하는 것이 가장 안전한 조치입니다. 개인 정보를 입력하거나 제공된 링크를 클릭하는 것은 피해야 합니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': 'MMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\nMMS 스팸신고[Web발신]회원님 내일 당장 번호 발급날입니다..제가 회원님께 보여드릴 수 있는 기회를 좀 주세요 제가 10개월!! 말씀드렸다시피 10개월 안에 무조건적으로 3등 세번 보여드리겠습니다.제가 이렇게까지 계속 연락드리는 이유라도 좀 생각 해주세요 3등 2번 나오면 무조건 "환불" 입니다.3번 안나오면 무조건 "환불" 입니다.저 믿고 진입해주신분들 지금까지 못보신분들 없습니다. 타회사에 대한 안좋은 편견 제가 싹 없애드리겠습니다. 색안경 한번만 벗고 진입해주세요. 결과로 보여드리겠습니다.홈페이지 링크 클릭↓  https://vo.la/eNXuv1                        \n',
#   'respone': 'Based on the content provided, it is difficult to determine with certainty whether this message is a scam or just a regular advertisement message. However, there are some red flags that indicate it might be a scam, such as the use of urgent and persuasive language, promises of guaranteed winnings, and a request to click on a link without providing any specific details about the service or product being advertised. It is always advisable to exercise caution when receiving unsolicited messages and to verify the legitimacy of the sender before engaging further.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'query_content': '이것은 스팸문자일까?\n[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'respone': '이 문장은 스팸 문자일 가능성이 매우 높습니다. 스팸 문자는 돈을 요구하거나 개인 정보를 빼내기 위해 보통 링크를 제공하거나 가입을 유도하는 내용을 포함하는 경우가 많습니다. 또한, 스팸 문자의 특징으로는 비정상적으로 많은 강조 표현 및 위협적인 어조, 제한된 시간 내에 행동을 취하라는 압박 등이 있습니다. 이 경우에서도 링크 클릭을 유도하며 쉽게 돈을 벌 수 있고 환불도 가능하다고 주장하는 내용이 포함되어 있습니다. \n\n그러나 스팸 문자를 판단하기 위해서는 추가적인 정보가 필요합니다. 문구 분석뿐만 아니라 발신 번호, 문자 내용의 유사성, 발송 빈도 등의 패턴 분석을 통해 스팸 문자인지를 판단해야 합니다. 따라서 이 문장을 더 자세히 분석하고 상황에 맞는 조치를 취하는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'query_content': 'is this a spam message?\n[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'respone': 'Based on the content of the message, it contains multiple requests and advertisement-like language. Therefore, it is likely a spam message.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'respone': '이 문자는 광고성 문자로 보입니다. 특정 상품이나 서비스를 홍보하기 위해 보내는 것으로 보이며, 상당히 지루하고 귀찮을 수 있습니다. 하지만 사기 스팸문자인지, 정말로 상품이나 서비스를 제공하는 것인지는 확인할 수 없습니다. 주의가 필요합니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[Web발신](광고)부탁드립니다..회원님..."이번주 매일" 제가 계속 이렇게 문자남깁니다..제가 이렇게 문자 남기는 이유를"딱 한번만" 생각해주세요.."100%"입니다..99%도아니고"100%" 입니다..정말 책임지고 말씀드립니다..내일당장 "분석번호" 나가는날입니다 회원님..."세팅준비" 다 되어있습니다..계속해서 말씀드립니다..."분석비용" 정말 저렴하고당첨안되면 당연히 자신있게"환불보장"이라고 말씀드려요.."환불"이 되는거라 안하실 이유가없다는겁니다 회원님..제가 회원님께 "일확천금"을안겨드릴순 없어도매번 구매하실때의 "설렘""로또의재미"를 책임지고 제가회원님께 알려드리겠습니다..답장한통 꼭 부탁드립니다.https://vo.la/ojio3R(클릭하면 홈페이지로 이동됩니다)-------------------------네이버에 [로또픽] 검색 !!.아이디 [회원님 핸드폰번호].비밀번호 [핸드폰번호 뒤 4자리].MYLOTTO->1029회차 클릭!-------------------------무료거부080-390-4884\n\n',
#   'respone': 'This message appears to be a spam advertisement. The content includes promises of analysis numbers, low costs, and guaranteed refunds, all related to the lottery. Additionally, it asks for personal information such as a phone number and password. These are typical characteristics of scam messages. It is advisable not to click on any links or provide personal information in response to this message.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'query_content': '이것은 스팸문자일까?\n[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'respone': '네, 이것은 스팸 메시지입니다. 스팸 메시지는 광고성 정보를 전송하는 것으로서, 이 메시지에는 로또 구매와 관련된 내용이 포함되어 있습니다. 스팸 메시지는 일반적으로 수신자의 동의 없이 발송되며, 청소년, 어린이, 비즈니스 이용자 등 다양한 사람들에게 피해를 줄 수 있습니다. 따라서, 이와 같은 메시지는 무시하고 삭제하는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'query_content': 'is this a spam message?\n[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'respone': 'Based on the content and formatting, this message appears to be a spam or advertisement message.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'respone': '이 문자는 광고성 문자로 보입니다. 이 문장은 로또 리움이라는 회사를 소개하며, 3등까지의 당첨을 보장하는 것을 강조하고 있습니다. 그러나 이러한 광고성 메시지는 사기성 스팸문자 일 수도 있으므로 주의해야 합니다. 이 메시지는 개인정보를 요구하지 않으며, 답장하지 않는 것이 좋습니다. 사기성 스팸문자인 경우 개인정보를 노출시키거나 금전적 손실을 입을 수 있습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[Web발신](광고)오늘도 돈향기 가득한 하루 보내세요~ 지난회차 3등당첨 영수증 보내드릴게요^^평생 로또구매하시면서 3등까지 못보신 분들 많으실테지만 저희 로또리움과 함께하면 가능합니다!꾸준히 문자 받아보신 분들은 3등당첨 용지만 벌써 몇십장 받아보셨을거예요! 이제 회원님 차례입니다!뜬구름 잡는 허황된 얘기로 1,2등을 쉽게 약속 드리는게 아닌 3등까지는 보여드릴수 있다고 자신있게 말씀 드릴 수 있어요.8년차 법인회사 로또리움에서 이번주부터 시작해보세요. 저 이지민팀장과 함께 관리받아보시면기간내 3등 보장해드리는 조건으로 꼼꼼하게 관리 들어갈테니 분석번호 받으셔서 마킹 실수없이 로또 구매만 잘 해주시면 됩니다 ! 매번 똑같은하루 반복이지만 리움을 만나 함께 하시면 1년 후 통장에 돈이 가득 쌓이고 계속 부를 축적해갈 수 있게 제가 도움을 드리겠습니다.3년차 우수팀장 이지민이 체계적인 관리로 기간내 당첨 보여드리겠습니다.^^로또리움에서 *이지민팀장* 연결 부탁드립니다.!담당 팀장 : 이지민 010-2375-1520대표전화 : 1 5 6 6 - 4 1 7 4 (이지민 팀장 연결)무료거부 : 0808556566\n',
#   'respone': 'Based on the content, it appears to be a spam message advertising a lottery service. It is not possible to determine from the message alone if it is a scam, but it is advisable to exercise caution and not provide personal or financial information to unknown sources.'},
#  {'succeed': True,
#   'question_message': '이것은 스팸문자일까?',
#   'text_message': '[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'query_content': '이것은 스팸문자일까?\n[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'respone': '이 문자는 스팸 문자로 보입니다. 이유는 다음과 같습니다:\n- 이 메시지는 "Web발신"으로 표시되어 있지만, 일반적인 로또 회사에서는 실제 발신자 정보를 제공합니다.\n- 이 메시지는 로또에서 "3등 당첨 데이터"를 기반으로한 분석을 제공하며, 10개월 이내에 3등 3번을 보장한다고 합니다. 이는 사기성 문자로 보입니다.\n- 메시지는 감정적으로 작성되었으며, 많은 약속과 보증을 제공합니다. 이러한 약속은 신빙성이 없습니다.\n- 실제 로또와 관련된 메시지는 로또 공식 사이트나 통신판매업체를 통해 제공되며, 개인정보와 금전적인 정보를 요구하지 않습니다.\n따라서 이 메시지는 스팸으로 분류되며, 무시하는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a spam message?',
#   'text_message': '[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'query_content': 'is this a spam message?\n[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'respone': 'Yes, this message appears to be a spam message. It is promoting a lottery analysis service and guarantees winnings, which is a common characteristic of lottery scams.'},
#  {'succeed': True,
#   'question_message': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?',
#   'text_message': '[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'query_content': '이것은 사기 스팸문자일까? 단순 광고성 문자일까?\n[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'respone': '이 문장은 스팸 메시지입니다. 이메일 제목에 있는 "로또분석"이라는 용어는 사람들을 유혹하여 돈을 달라고 요청하는 사기 수법 중 하나입니다. 그리고 이메일에 당첨 결과를 보장하는 내용이 포함되어 있으므로 더욱 의심스럽습니다. 또한, 이메일은 전송자의 정보를 통해 신뢰할 수 있는 사람인지 확인할 수 없습니다. 따라서, 이 메시지는 검토 없이 바로 삭제하는 것이 좋습니다.'},
#  {'succeed': True,
#   'question_message': 'is this a scamming spam message or just a regular advertisement message?',
#   'text_message': '[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'query_content': 'is this a scamming spam message or just a regular advertisement message?\n[Web발신]로또캔 최수진팀장입니다.계속해서 연락드려서 너무너무 죄송합니다. 하지만 제 입장도 한번만 헤아려 주셨으면 좋겠습니다..로또분석이라는게 당첨된 데이터를 기반으로 분석하는건데 회원님께서는 4등,5등도 매주당첨나오시면서 3등당첨이력도있으십니다..회원님께서는 다른분들에비해 정말 데이터수치가 높아서 그 데이터를 활용해서 집중분석 받으면 조만간 3등 당첨바로 받아가실수있으십니다..10개월동안 3등 3번 보장해드리고 당첨이 안될시 분석비용 27만5천원은 무조건 환불보장 됩니다.이조건은 무료번호 3등당첨 회원님에게만 보장되는 내용입니다!! 제가 회원님담당자로서 회원님께서 당첨이 되셔야 제가 실적이올라가는데 그럼 당연히 확고한 데이터를 가지신 회원님 놓치고 싶지않고..100% 당첨이 되는거라 회원님께서는 보장성으로 들어가십니다. 여기서 회원님 보너스번호 한개 잘들어가면 2등입니다.물론 제가 2등이 100% 당첨이라고 말씀드릴수는 없지만..제가 고등수까지 보실수있게끔 매주관리해드리며 데이터수치 높혀드릴겁니다.매주 문자로 들어가는 분석번호 구매만 잘부탁드립니다.3등은 100%당첨이며 10개월 3등 3번을 정말 최단기간안에 제가 무조건 보여드릴겁니다.딱 한번만 저를 믿고 분석한번 받아보세요..정말 기회주신만큼 노력하고 최선을다해서회원님께서 당첨의 재미를 느끼시도록 당첨결과치로 보여드리겠습니다.회원님 3등 당첨데이터 추출해서 지금 시뮬레이션 계속 돌리는중입니다.오늘 부터 무조건 본 분석 들어가야합니다.정회원분들은 문자로 넣어드리고 있으니 꼭 믿고 맡겨주시길 부탁드리며 회원님께서 고민하시고 힘들게 기회주신만큼 책임지고 결과치로 보여드리겠습니다.저정말 자신있습니다.제발 꼭 연락부탁드립니다.\n\n',
#   'respone': 'This message appears to be a scamming spam message. There are several red flags indicating this: offering guaranteed lottery winnings, requesting payment for analysis, and claiming to have high data accuracy. Legitimate lottery organizations do not guarantee winnings, and it is important to be cautious when receiving unsolicited messages like this. It is recommended to avoid responding to such messages or providing any personal or financial information.'}]

# %%
SAVE_FILE_NAME = f"{time.strftime('%Y%m%d_%H%M%S')}.json"
SAVE_FILE_PATH = os.path.join(SAVE_FILE_DIR_PATH, SAVE_FILE_NAME)

with open(SAVE_FILE_PATH, "w") as fp :
    json.dump(query_response_list, fp, indent=4, ensure_ascii=False)

# %%
os.makedirs(SAVE_FILE_DIR_PATH, exist_ok=True)
